# %% [markdown]
# **Progetto d'Esame Scientific Python**
# *Autori*:
# - Gaia Donzelli.
# - Simone Raimondi.
#
# **Breve descrizione informativa**
# In questo notebook è presente la simulazione del fenomeno sm-FRET (Single Molecule-Förster Resonance Energy Transfer) compresa di discussione teorica del fenomeno e di elaborazione dati.
#
# In particolare l'analisi verterà sulla simulazione del comportamento di una molecola singola a cui vengono aggiunti due traccianti (fosfori emettitori e assorbitori) per studiarne l'apertura e chiusura, seguita dal fitting dei dati simulati per recuperare il comportamento e le distribuzioni di probabilità dei due stati. L'intera analisi sarà realizzata implementando simulazioni Monte Carlo per la realizzazione della molecola e algoritimi Makov-Chain Monte Carlo (MCMC) per l'identificazione di parametri nascosti al fine di caratterizzare completamente il fenomeno.
#
# L'articolo da cui trae ispirazione questo progetto è presente al link https://www.sciencedirect.com/science/article/pii/S0006349506719038#fig4.
#
# Qui di seguito è presente la cella dedicata alla bibliografia impiegata per l'esecuzione del progetto.
#
# **Bibliografia**
#
# [1]  Sean A. McKinney, Chirlmin Joo, Taekjip Ha, *Analysis of Single-Molecule FRET Trajectories Using Hidden Markov Modeling*, 2009, Department of Physics and Howard Hughes Medical Institute, University of Illinois at Urbana-Champaign, Urbana, Illinois.

# %%
'''
Cella di import delle librerie principali:
'''

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import emcee as mc
import corner as mc_vis

# %%
print("ciao")
